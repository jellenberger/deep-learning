# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:08, 3.88MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random
import numpy as np
from collections import Counter

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
word_freqs = {word: count / total_count for word, count in word_counts.items()}
word_pdrop = {word: np.sqrt(threshold/freq) for word, freq in word_freqs.items()}
train_words = [word for word in int_words if word_pdrop[word] < random.random()]
print(len(int_words), len(train_words))
# Out:
# 16680599 12053690

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1, window_size + 1)
    start = idx - r if (idx - r) > 0 else 0
    stop = idx + r
    target_words = set(words[start:idx] + words[idx + 1: stop + 1])
    
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1, dtype=tf.float32, name='embedding')
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 9.1221 0.0306 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 9.0676 0.0241 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 9.0406 0.0238 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 9.0652 0.0236 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 8.9473 0.0235 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 8.9503 0.0234 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 8.9307 0.0230 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 8.8522 0.0231 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 8.7550 0.0230 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 8.6917 0.0230 sec/batch
# Nearest to new: nord, juror, arda, bakesperson, euratom, word, plp, insensitivity,
# Nearest to about: ath, pixar, kubitzki, drastic, demonstrations, dionysius, archbishopric, harker,
# Nearest to american: erasmus, brooklyn, emporia, texas, nutation, wan, maser, surprised,
# Nearest to after: cherished, serres, kubrick, chemical, bahmani, lincolnshire, nibble, vcjd,
# Nearest to by: icct, appointment, embarrassment, alloy, trotsky, inking, licenced, syntagma,
# Nearest to and: linemen, phenomenalism, built, strata, suzerain, lame, gurdjieff, argentino,
# Nearest to five: imperfectly, consults, appeals, hwang, commit, cambodian, himachal, coated,
# Nearest to d: redirection, defender, rudolph, magnolia, neuralgia, depressants, faults, mboxx,
# Nearest to articles: cabalistic, soderbergh, delaney, oxide, iraqis, hampshire, garten, voyages,
# Nearest to scale: myriad, governs, overwhelms, sin, flawed, philistine, flicker, vladimir,
# Nearest to heavy: attackers, carmelites, monsanto, amyraut, hoofed, greedy, shawcross, cohen,
# Nearest to derived: bearable, calabrian, involuntarily, euglenids, powder, iau, specialists, legally,
# Nearest to egypt: malky, alphabetically, pediatrics, ahimelech, overheating, trumbo, downloads, euphemisms,
# Nearest to powers: untso, schoolmates, testimony, parliamentarism, brescia, bewitched, categories, amalric,
# Nearest to bbc: laodiceans, tillman, shorten, disloyal, rangle, poulsen, shearer, tyndall,
# Nearest to creation: roe, pashto, salaino, sarmatian, master, mush, raped, yersinia,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 8.5941 0.0242 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 8.5591 0.0232 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 8.4991 0.0231 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 8.4395 0.0232 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 8.3469 0.0232 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 8.3009 0.0232 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 8.1887 0.0233 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 8.2004 0.0232 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 8.1516 0.0231 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 8.0476 0.0231 sec/batch
# Nearest to new: isolationists, naxos, fouch, teuton, civilized, column, chloroform, andamanese,
# Nearest to about: passes, versailles, presidentially, randy, afrika, muselar, glycosides, aphorisms,
# Nearest to american: danced, memorize, vyasa, certification, dutch, abbott, toledo, natalie,
# Nearest to after: shahnama, henchmen, teamsters, populares, forschung, achilles, attu, notations,
# Nearest to by: boyfriend, flocking, autobiographic, kohlberg, southampton, revert, chueca, shaper,
# Nearest to and: collor, eno, provocative, limerick, acrocorinth, adders, trichechus, arming,
# Nearest to five: fy, curling, psc, zapatista, feudal, metadata, secretive, discant,
# Nearest to d: pumping, distressing, animalia, kinesthetic, musculature, revealing, consciousness, nanotechnology,
# Nearest to articles: dialectic, crb, hatch, inferno, humber, pagoda, state, doren,
# Nearest to scale: persuades, inc, shearing, bremsstrahlung, draped, predicates, walruses, loaf,
# Nearest to heavy: confocal, malaria, katie, refrigerated, benelux, veneziano, swell, hungry,
# Nearest to derived: gallo, benzedrine, cyrillic, farther, baar, whistler, jansenist, guzman,
# Nearest to egypt: politiques, schuler, edgy, dispossessed, wingtip, timescale, eps, disagreeable,
# Nearest to powers: decayed, sight, lasker, housman, tunic, serbs, ogc, subgenre,
# Nearest to bbc: rebranded, chromosphere, loveline, blaming, yster, por, subfamilies, liminal,
# Nearest to creation: criminalization, grandstand, avowedly, ethnicities, carisbrooke, dianetic, bihar, unconsciousness,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 8.0211 0.0243 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 7.9603 0.0231 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 7.9461 0.0231 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 7.8684 0.0229 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 7.7675 0.0232 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 7.6957 0.0232 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 7.6917 0.0230 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 7.5248 0.0232 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 7.5309 0.0231 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 7.5166 0.0230 sec/batch
# Nearest to new: abaddon, pastimes, peaches, subiaco, sef, icao, elkhart, turismo,
# Nearest to about: graphic, warms, wrangel, langland, boulevards, guyane, experiments, inconsistent,
# Nearest to american: mackerel, myers, stripping, morality, toast, evatt, backdoor, vauquelin,
# Nearest to after: embodying, sm, dominic, ashtoreth, connotation, trier, crank, digambar,
# Nearest to by: belli, tiered, pros, deviations, hessen, unoccupied, airport, recipients,
# Nearest to and: exploit, nomen, refurbishment, pursuit, riverside, statistically, stadt, sata,
# Nearest to five: susumu, unemployed, mantua, jam, fruitless, personnel, wraparound, halo,
# Nearest to d: css, banjar, unsuccessfully, josephus, theresia, guant, organizers, jerry,
# Nearest to articles: hinders, layouts, conjugacy, willem, tasman, sketches, brookline, equating,
# Nearest to scale: keying, refuting, algiers, jagiellonian, duhem, permanent, caller, capping,
# Nearest to heavy: monologues, estonia, fluffy, suppress, everest, mantra, predicted, livio,
# Nearest to derived: velvet, regina, abolished, vocations, pegging, sayonara, faust, carlson,
# Nearest to egypt: distressed, criticism, mnism, percentile, descendant, philanthropy, indefensible, hateful,
# Nearest to powers: deadpan, gmbh, motorist, mauricien, jericho, haywood, huygens, formosa,
# Nearest to bbc: stylebook, tempel, shasta, buryat, coronado, kyrie, descending, choice,
# Nearest to creation: phoebastria, passy, weidman, scholastics, petrarca, intelligibility, library, surabaya,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 7.3877 0.0242 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 7.3675 0.0231 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 7.3180 0.0231 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 7.2156 0.0231 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 7.1901 0.0231 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 7.1034 0.0230 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 7.1117 0.0232 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 6.9981 0.0231 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 6.9682 0.0232 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 6.9045 0.0231 sec/batch
# Nearest to new: meme, wants, consequentialism, conceptualization, breckinridge, fricative, worshippers, denial,
# Nearest to about: emoticons, tchaikovsky, sda, ville, dehydrogenase, guybrush, parvati, solving,
# Nearest to american: snp, embarrassed, culling, alistair, lithographica, dispatches, frontispiece, cuboctahedra,
# Nearest to after: groundhog, namek, epr, resale, sml, darnley, erat, perform,
# Nearest to by: predicting, gormenghast, earner, ordnance, pcb, loreto, theban, unsanitary,
# Nearest to and: duras, mctell, prophets, selenium, inklings, fpss, centred, murdoc,
# Nearest to five: resemblances, habermas, gia, igor, mime, supervising, ongoing, detects,
# Nearest to d: priority, camus, nested, nagarjuna, sportswriter, marcia, lasted, appliqu,
# Nearest to articles: distilling, ferris, maximise, prescribing, exertion, cauliflower, bundeswehr, empties,
# Nearest to scale: oceanography, seawater, porcelain, weave, plinth, fugazi, mtbe, dalrymple,
# Nearest to heavy: discrimination, cabins, walid, bolo, powerplant, nonspecific, payout, humiliated,
# Nearest to derived: vuk, journeyman, feudalism, baptismal, grows, portuguese, zog, judicially,
# Nearest to egypt: prefering, pickets, kleene, forint, timaeus, uncanny, apoptosis, hanzei,
# Nearest to powers: akihito, unplanned, osbournes, clements, hornets, haggadah, taito, reconstructionism,
# Nearest to bbc: kabul, isotropic, patrolling, matilda, ticonderoga, fruiting, superclasses, incubus,
# Nearest to creation: stunned, unce, cido, salat, lorien, carne, iho, cois,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 6.8539 0.0241 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 6.7934 0.0231 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 6.7757 0.0231 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 6.7088 0.0231 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 6.7251 0.0229 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 6.6198 0.0231 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 6.6015 0.0230 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 6.5147 0.0233 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 6.4833 0.0231 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 6.4322 0.0231 sec/batch
# Nearest to new: sheol, aerobatics, involve, hosea, versioning, coenzyme, scarred, vyasa,
# Nearest to about: rows, amish, cleaveland, baddeck, tibetans, deceitful, rinzai, clay,
# Nearest to american: excommunicated, deutscher, cultus, benthic, propel, kucinich, nie, rival,
# Nearest to after: theroux, haitians, laker, induced, marginalised, lira, ishi, ferries,
# Nearest to by: respondents, renumbered, nella, tenuous, thalberg, bronson, busby, mixes,
# Nearest to and: sorrows, garrisons, polka, pending, botanical, sinatra, unprepared, fling,
# Nearest to five: gwh, percieved, cascade, defrauding, lanarkshire, ries, edition, urination,
# Nearest to d: anachronism, mmorpg, uncomfortable, dream, ooze, lusthog, pyrrhic, sufis,
# Nearest to articles: doomed, flock, receding, dispensation, jim, ap, stratosphere, myles,
# Nearest to scale: pickups, physicists, bamileke, cape, dunkeld, centum, burgh, mutton,
# Nearest to heavy: nubcake, bentheim, realises, deteriorating, toolkit, voc, augusti, cotswold,
# Nearest to derived: elihu, kimbundu, dramatized, paula, vidal, lain, vendor, matthau,
# Nearest to egypt: gelfand, bolan, handbooks, teleological, scivias, organometallic, carroll, crispy,
# Nearest to powers: supposed, kao, illawarra, phosphine, clarendon, intelligentsia, keokuk, guevara,
# Nearest to bbc: spellings, tyres, exploit, gelasian, awakens, gabriel, bushido, bijection,
# Nearest to creation: hmmwvs, legis, retrofit, kids, grupo, quill, napkin, greenfacts,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 6.3158 0.0243 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 6.3299 0.0233 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 6.2715 0.0231 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 6.2010 0.0232 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 6.1787 0.0230 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 6.1250 0.0233 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 6.0513 0.0233 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 6.0127 0.0231 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 5.9694 0.0231 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 5.9608 0.0232 sec/batch
# Nearest to new: pericardium, perceive, asb, trapdoor, forestry, newtonian, feburary, getter,
# Nearest to about: tauri, fouled, chalcis, cumont, cloak, hushed, bend, siegel,
# Nearest to american: unitar, architects, disregard, defended, dynastic, purchases, athene, iii,
# Nearest to after: intersystems, robespierre, eteocretan, fang, palamas, lecturers, grimoald, intermission,
# Nearest to by: humvee, confrontational, rubble, dislocations, nightbreed, humid, derided, deallocation,
# Nearest to and: claes, neolithic, cybernetica, yell, barrie, precipitates, highpoint, ipkf,
# Nearest to five: jesse, ruby, rdenas, subregions, meister, cradle, indole, crusade,
# Nearest to d: snafu, harpsichordist, mitrailleuse, nissan, eubacteria, encouragement, olympia, snares,
# Nearest to articles: printf, hills, antonyms, arundel, deport, hydrogen, metallica, slum,
# Nearest to scale: mathers, goldie, minimi, recreation, escorted, tanach, ghat, gene,
# Nearest to heavy: battersby, interoperate, testified, greenspan, hon, proportional, kbe, doak,
# Nearest to derived: tempestuous, ishaq, respectively, install, mmo, resilient, participant, romansh,
# Nearest to egypt: stoner, exe, tissue, bandmate, kishore, agouti, mimsy, chased,
# Nearest to powers: awm, gigantopithecus, superego, augusta, mesons, ifr, naples, bissell,
# Nearest to bbc: agincourt, cullen, dred, denmark, temporalities, inflows, regimental, bce,
# Nearest to creation: alemannia, pelagius, modifies, collectivized, intertwined, autres, litchfield, roberta,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 5.9031 0.0242 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 5.9271 0.0230 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 5.8640 0.0229 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 5.8587 0.0229 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 5.7172 0.0230 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 5.6833 0.0230 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 5.6472 0.0232 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 5.6239 0.0232 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 5.5729 0.0232 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 5.5138 0.0230 sec/batch
# Nearest to new: red, illiteracy, rockall, tarrant, stepmania, connecting, rephlex, sess,
# Nearest to about: zuse, quod, unchangeable, vip, brotherly, opined, caiman, logitech,
# Nearest to american: impair, champions, tubes, laredo, dispel, depeche, unmaking, unorganized,
# Nearest to after: troll, stefani, labyrinths, shek, delors, shoku, carlow, fosbury,
# Nearest to by: praecox, sparrowhawk, harnack, approximates, lit, dioxin, radiography, howls,
# Nearest to and: weiss, mvd, beli, baikonur, briand, unary, winterfell, simultaneously,
# Nearest to five: aconcagua, unionists, multipart, saviola, scarcity, conservatism, svante, yorkers,
# Nearest to d: addiscombe, hurston, myung, tat, cardinal, peninsula, rehabilitate, footballer,
# Nearest to articles: creoles, cleese, resizing, progressions, baird, rennie, emergent, sayles,
# Nearest to scale: collaborationist, josep, tert, mma, alberts, jonah, prompting, saar,
# Nearest to heavy: sensing, pneumoniae, choosing, abdicated, fiduciary, sih, muscovites, metaphysician,
# Nearest to derived: coldcut, hinnom, inclination, cryptology, confidential, using, rows, oblige,
# Nearest to egypt: tora, utilises, synagogue, ccc, necessarily, seminumerical, kli, strain,
# Nearest to powers: mordor, entrenchment, flawlessly, symonds, genealogists, thirteenth, functionality, romantically,
# Nearest to bbc: affluence, classificatory, caller, alle, scalloped, rundstedt, purpurea, ideal,
# Nearest to creation: technologically, becket, billiards, hydrogenation, rishi, klux, rampant, electorate,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 5.4680 0.0241 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 5.4806 0.0231 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 5.4102 0.0232 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 5.4052 0.0232 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 5.4207 0.0231 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 5.3405 0.0231 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 5.2978 0.0232 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 5.2843 0.0231 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 5.2768 0.0232 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 5.2187 0.0231 sec/batch
# Nearest to new: amplitudes, sprockets, exporter, specialties, clemente, bitola, marca, unifies,
# Nearest to about: olga, doped, diverging, hereby, blindly, tartan, moe, distributes,
# Nearest to american: haeckel, extant, chronica, gj, cryonicists, surrenders, vall, pacts,
# Nearest to after: submersible, redshifted, festivals, mints, likud, bissell, coms, seating,
# Nearest to by: heartbeat, gland, cheapest, destruction, gua, mooring, rocket, executive,
# Nearest to and: kushner, eph, permitting, exchanges, modernizations, endosymbiont, mendelians, supernatural,
# Nearest to five: scrape, greenland, sakae, bowler, implements, dbase, farouk, ghc,
# Nearest to d: newline, shareholders, denmark, mia, laureate, sneakers, hamadan, spamalot,
# Nearest to articles: synchronised, clockwork, honouring, krulak, variability, atoms, palos, vineyards,
# Nearest to scale: legality, foiled, commencing, locrian, visions, biochemists, francesc, klan,
# Nearest to heavy: logged, gwp, graceful, eyelashes, each, stereotype, instructed, joyous,
# Nearest to derived: theories, boucher, elimelech, holmes, latencies, spelt, eu, freezer,
# Nearest to egypt: personhood, stoic, unrwa, recreations, zaghawa, doses, randell, handled,
# Nearest to powers: chappelle, litha, widest, malatesta, upholds, cathodes, database, mindanao,
# Nearest to bbc: courtier, spousal, migrants, frozen, misfits, chickens, epstein, lord,
# Nearest to creation: identical, sitter, subdiscipline, atta, coffee, ignatius, roped, mcclure,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 5.1880 0.0243 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 5.1609 0.0233 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 5.1214 0.0231 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 5.1648 0.0232 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 5.0940 0.0231 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 5.0744 0.0231 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 5.0739 0.0230 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 5.0384 0.0232 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 5.0450 0.0231 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 5.0189 0.0232 sec/batch
# Nearest to new: liver, pendant, neurosurgery, propellers, revolved, tsunami, header, lewdness,
# Nearest to about: katie, restated, nuit, walloon, quips, amistad, worms, ninja,
# Nearest to american: lichtenberg, heflin, abaye, thrift, grace, merced, lxxviii, kombat,
# Nearest to after: syntactically, proverb, petite, subarctic, whoso, colleague, dispensationalism, halevi,
# Nearest to by: textured, wftu, daoxuan, confining, courier, haphazard, nagorno, sarkozy,
# Nearest to and: mythological, jumaada, settled, gestapo, bless, climax, rounded, remakes,
# Nearest to five: bamiyan, eurotunnel, evocative, way, invitational, recognizable, moores, kames,
# Nearest to d: khmer, radicals, chickpea, slocum, praetor, heterosexuality, klia, fixation,
# Nearest to articles: neighbor, ericsson, hasdrubal, sc, february, halloween, zohar, privy,
# Nearest to scale: gatsby, rup, ne, bourdon, pronouncement, poignant, annie, stapleton,
# Nearest to heavy: exhausted, tchaikovsky, maintain, cabell, gig, chera, eristic, stabilizing,
# Nearest to derived: dp, biruni, beckenbauer, assassins, commercialize, ade, chorus, cern,
# Nearest to egypt: illegible, tibia, throes, yoakam, psychiatrist, decides, hiding, colombia,
# Nearest to powers: regimes, intermedia, ford, bohdan, archie, womanizer, informed, gujarat,
# Nearest to bbc: crystallization, cytosol, tightened, klux, interethnic, stay, undoubted, mcintyre,
# Nearest to creation: scam, nonalignment, hooded, prolog, breakaway, ai, slurs, interchangeably,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 5.2124 0.0238 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 5.0576 0.0229 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 5.0428 0.0229 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 5.0150 0.0229 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.9348 0.0232 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.9385 0.0232 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.9125 0.0232 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.9007 0.0230 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.8669 0.0232 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.8617 0.0231 sec/batch
# Nearest to new: lincolnshire, ibrd, tamil, justine, anglesey, abate, jonestown, roused,
# Nearest to about: quizzes, hina, spector, worthies, revolving, mediocre, rhone, staunton,
# Nearest to american: goodtimes, technologists, mysticism, differentiation, kamikaze, imperatoribus, native, anthologies,
# Nearest to after: arse, overtone, fanbase, kanto, finno, annexed, bamboo, rahxephon,
# Nearest to by: francoist, imams, mariners, liutprand, apothecaries, vitry, alpha, official,
# Nearest to and: poee, nts, manipur, konerko, jts, protostomes, publicacion, blumenthal,
# Nearest to five: supernovae, turgidson, watchdog, taino, norte, introspection, naturalis, supersede,
# Nearest to d: pinckney, milligan, salamanders, treasurer, puns, chilean, notes, translational,
# Nearest to articles: spectrometry, demi, ascension, corinth, realizes, peloponnesian, famille, konig,
# Nearest to scale: mcc, pejorative, yen, khomeini, kittiwakes, vyasa, pharmacists, gehry,
# Nearest to heavy: experimentalists, contraceptives, origins, kills, signor, slums, carrera, summerson,
# Nearest to derived: tastes, diyala, corporation, gillies, smiled, occidentalis, pk, hmc,
# Nearest to egypt: obrenovi, quadrupole, reserving, fairclough, hens, ministers, exchanges, scurvy,
# Nearest to powers: offers, karo, aquarist, shui, derives, withholding, stride, mifune,
# Nearest to bbc: thriving, cotonou, bearers, irritate, alesia, kab, seafarers, trivially,
# Nearest to creation: argent, factional, matriarch, cyclones, metaplot, origins, externalism, computerised,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.8684 0.0241 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.8816 0.0232 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.8563 0.0232 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.8524 0.0231 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.8369 0.0229 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.8296 0.0230 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.8371 0.0232 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.8474 0.0231 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.8087 0.0229 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.8014 0.0230 sec/batch
# Nearest to new: ubi, southbound, crystallization, whores, weil, renderer, louisville, nagorno,
# Nearest to about: antiprotons, lata, expounding, rendezvous, bulgarians, enthalpy, consumer, acoustic,
# Nearest to american: rhineland, capitalisation, burgundy, dido, conventual, upon, rations, playboys,
# Nearest to after: eeoc, match, foamy, chancellorship, commentators, colonizers, magnified, pinus,
# Nearest to by: mythology, pungent, darya, clockrate, aftermath, princeton, customs, hamming,
# Nearest to and: accolade, vidzeme, hertfordshire, autochthonous, sandbox, alaric, letting, talib,
# Nearest to five: contracts, physica, pembroke, machado, csonka, paglia, contradictions, significant,
# Nearest to d: psychotherapists, extrinsic, pubs, lenstra, tommaso, clap, movers, amaury,
# Nearest to articles: rsdlp, wenceslaus, lehigh, neruda, velocities, abilities, hangzhou, flamenco,
# Nearest to scale: schine, scanlon, freenet, addressee, coloured, uan, awaited, zseries,
# Nearest to heavy: went, arrakis, mandibles, raye, liberalisation, starches, dollywood, industrialized,
# Nearest to derived: nsdap, domestication, sceptics, boece, orthopedic, akiva, mab, conquests,
# Nearest to egypt: electrolytic, caddies, matsushita, shimizu, humphries, doordarshan, licensed, lambs,
# Nearest to powers: hauer, performance, sandstone, blot, crawler, flensburg, linehan, anthology,
# Nearest to bbc: librarian, wanting, momentary, dmitry, solemn, paucity, roofs, naples,
# Nearest to creation: induces, heralds, tootsie, nrc, cowan, dominicans, uttered, hihat,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.8093 0.0241 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.8143 0.0233 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.8146 0.0231 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.7895 0.0233 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.7637 0.0232 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.7622 0.0232 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.7632 0.0230 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.7022 0.0230 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.7386 0.0232 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.7373 0.0232 sec/batch
# Nearest to new: valadon, scrying, raptors, meritocratic, rookies, verge, margarete, electrolysis,
# Nearest to about: alberti, frente, mjh, seal, abkhazians, alloy, ramanujan, amigas,
# Nearest to american: gut, gooch, krestinsky, typed, cannibals, imad, send, konami,
# Nearest to after: lemy, modernised, biotech, arlo, cq, wheels, recital, sanders,
# Nearest to by: fro, memetic, semipalatinsk, biruni, doctorate, flintstones, abe, havenco,
# Nearest to and: pope, absorbs, cinque, pasteur, ladislaus, rde, sparteca, pyrimidine,
# Nearest to five: fullness, vergina, imperfectly, empowerment, tatar, addresses, wein, circling,
# Nearest to d: khaled, series, distinguish, americium, kiritimati, crozier, nagako, prove,
# Nearest to articles: jeppesen, legume, karakoram, kipsigis, midrash, hg, henchmen, unspeakable,
# Nearest to scale: wat, excommunicating, nats, chromatically, jw, piau, grinding, kenya,
# Nearest to heavy: petrovich, sanjak, elaboration, lodovico, lens, next, neurons, macpherson,
# Nearest to derived: crack, fortuitous, eggs, fatalism, cui, investments, absorbed, evidential,
# Nearest to egypt: precincts, qwerty, westinghouse, mbta, jesuits, regime, recruiting, comptes,
# Nearest to powers: khedive, thermometers, encircled, actinopterygii, differentiation, roda, encouragement, xliv,
# Nearest to bbc: undying, elapsed, cooperates, optimates, domicile, etna, riffing, trappings,
# Nearest to creation: dmca, blog, shang, ghamdi, unobservable, maligned, fee, keg,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.7413 0.0116 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.7380 0.0232 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.7167 0.0233 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.6960 0.0231 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.7016 0.0232 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.6891 0.0231 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.6736 0.0230 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.6489 0.0230 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.6367 0.0229 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.6703 0.0230 sec/batch
# Nearest to new: tomorrowland, crokinole, sweeter, expansions, hospital, thuringiensis, duras, franchises,
# Nearest to about: bae, ambit, shams, prescience, jordanes, ives, spider, raiders,
# Nearest to american: digested, mounting, scalars, discontents, primrose, farms, crystallize, loneliness,
# Nearest to after: lexicon, cass, seceding, russ, skate, dissatisfaction, discovered, quelled,
# Nearest to by: wildly, heredity, vagueness, manche, mahuad, hanno, interlanguage, curzon,
# Nearest to and: sentimental, collective, drinkers, reveals, troll, magnate, couldn, entheogens,
# Nearest to five: babies, prancing, salts, gassed, conferred, hempstead, marina, sfor,
# Nearest to d: epp, spain, kiln, overcrowding, sein, tallis, mankind, geiger,
# Nearest to articles: housewives, uncritically, panning, reshot, heading, olympics, bedfordshire, withholding,
# Nearest to scale: closed, browns, maintain, abhorred, entertaining, mig, spruce, postponed,
# Nearest to heavy: mindedness, ordinated, sigur, tabular, lacoste, masons, lunel, althing,
# Nearest to derived: haryana, sudanic, purer, brainstem, fairhair, throes, erectus, kau,
# Nearest to egypt: ponte, denmark, perfecting, odes, outcrops, adipose, iga, premier,
# Nearest to powers: lifeform, starship, mppc, bleed, encode, ojibwe, tumulus, gish,
# Nearest to bbc: cohesive, comneni, ntgen, multiples, vms, mccartney, hats, fandom,
# Nearest to creation: brooms, placements, wargaming, giscard, vandal, ninhursag, francks, sweeteners,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.6698 0.0241 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.6809 0.0231 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.6557 0.0231 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.6184 0.0232 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.6774 0.0233 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.6341 0.0232 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.6544 0.0231 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.6630 0.0232 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.6567 0.0232 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.6498 0.0231 sec/batch
# Nearest to new: sunsets, essendon, john, pools, yun, rips, rail, demobilization,
# Nearest to about: bolden, nv, bojinka, outpost, yamuna, steamed, spielberg, kilda,
# Nearest to american: francesc, fend, teaspoons, traced, jass, nonetheless, malm, crossbows,
# Nearest to after: pelicans, carve, fouls, peregrine, centaurs, metamorphism, proliferate, morals,
# Nearest to by: deccan, roof, kroon, anoxic, skyhawk, galleys, guardant, predicate,
# Nearest to and: satrapy, witwatersrand, manorialism, hawley, recon, analytic, apologies, meta,
# Nearest to five: numbing, axles, fremen, isp, sonar, colloquial, rub, patria,
# Nearest to d: hapless, enhancing, cossack, elective, starch, bradycardia, timetable, homonym,
# Nearest to articles: deprecate, concerti, riding, ninety, theosophical, synergy, alliteration, kekkonen,
# Nearest to scale: goff, obedient, geological, devin, wintering, imperceptible, reconsider, sinful,
# Nearest to heavy: labonte, monos, mapmaking, linspire, bagoas, seamlessly, assume, hobson,
# Nearest to derived: silkworm, decreasing, prime, geologic, mb, purging, iuris, malagasy,
# Nearest to egypt: poultry, farts, headway, kannapolis, eastern, fitzalan, rc, crusts,
# Nearest to powers: mano, jakarta, islam, metals, insults, makarios, packed, unfaithful,
# Nearest to bbc: combinations, travelogues, benzedrine, amaryllis, oman, russian, asteroid, laver,
# Nearest to creation: told, morphisms, sprite, inadmissible, sqrt, jules, radioactive, toprock,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.6042 0.0243 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.6380 0.0232 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.6311 0.0233 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.5924 0.0231 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.5902 0.0231 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.6314 0.0232 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.5985 0.0232 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.6295 0.0231 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.6447 0.0234 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.6244 0.0234 sec/batch
# Nearest to new: disruptive, malevich, adenine, roars, slay, exam, drc, leftover,
# Nearest to about: abdel, robotics, candid, kanno, straws, shaving, dagome, heuss,
# Nearest to american: kaoru, thayer, millimeter, modernism, pavements, international, verant, cker,
# Nearest to after: tarkenton, stoa, avarice, pah, ingushetia, paleontological, wesley, dect,
# Nearest to by: villepin, scraping, embouchure, apertures, predictor, marguerite, eschrichtius, exemptions,
# Nearest to and: foils, doohan, allergic, pinto, tangiers, lder, bolo, diameter,
# Nearest to five: swamped, urges, trips, homework, quaid, hutchison, deus, meandering,
# Nearest to d: ate, monopsony, customized, leaped, bastnasite, returned, disclosures, immortalized,
# Nearest to articles: xxxi, foss, belmont, scaly, phillies, apparition, intersected, roadblocks,
# Nearest to scale: patio, errands, gaits, pierre, fineness, turkmenistan, individualism, ricketts,
# Nearest to heavy: calonne, defies, excised, trema, bettina, incriminating, malaysians, modifies,
# Nearest to derived: enhancements, beaver, selecting, ltd, levitt, britain, threads, mirabilis,
# Nearest to egypt: spells, phage, pathogens, shrew, markers, mellaart, verlag, commodores,
# Nearest to powers: respond, vla, halftime, refrained, hurl, devito, phipps, alys,
# Nearest to bbc: cuts, skated, gatt, udi, mismanaged, lamarr, mehmet, mw,
# Nearest to creation: hessians, achieved, announces, fizz, moshe, focuses, resources, fantastical,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.6049 0.0244 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.6218 0.0234 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.6079 0.0233 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.5928 0.0234 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.5815 0.0235 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.5846 0.0235 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.6383 0.0233 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.5788 0.0234 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.5636 0.0235 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.5836 0.0234 sec/batch
# Nearest to new: theodorus, hawley, midline, turnover, infidel, revived, emptying, haas,
# Nearest to about: acetate, nevertheless, faced, timbers, points, mesopotamian, caddying, night,
# Nearest to american: verdi, acquiring, complying, calamities, algebraically, casta, herbie, quintilian,
# Nearest to after: paste, influenzae, wording, oz, poking, aquarium, deposited, microeconomic,
# Nearest to by: igbo, oxbridge, assuming, psychotherapy, mor, watchful, blossom, aramean,
# Nearest to and: rita, midwife, tenn, complutense, nah, signification, novorossiysk, indicative,
# Nearest to five: qq, landowner, seventy, succubus, plymouth, meth, hodgson, echidnas,
# Nearest to d: bestselling, parted, endorse, classmate, judaeo, all, heritage, bottlenecks,
# Nearest to articles: lambasted, lessened, ionized, ciconiiformes, thrax, activities, gesture, slr,
# Nearest to scale: way, electrolysis, configurable, rashes, unseated, lderlin, exporting, encoding,
# Nearest to heavy: loops, rasterization, court, astrophysicists, enmity, rosters, evangelium, zionists,
# Nearest to derived: faithfully, colchester, conglomeration, ginny, prone, deeper, cerevisiae, melba,
# Nearest to egypt: singlet, indelible, hawaiian, merciless, damaged, lebanon, refuted, prefetch,
# Nearest to powers: begin, mistaking, lebanese, awry, meherabad, sacked, leith, cambridge,
# Nearest to bbc: saving, distress, instinctively, ay, exist, morningside, chart, jabber,
# Nearest to creation: rafael, burali, thither, flooding, lyman, tachyon, gibraltar, rourke,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.5661 0.0246 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.5759 0.0235 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.5705 0.0236 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.5624 0.0235 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.5660 0.0233 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.5693 0.0234 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.5695 0.0234 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.5487 0.0233 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.5597 0.0233 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.5403 0.0234 sec/batch
# Nearest to new: itanium, monosaccharide, bioprospecting, detachable, rees, apportioned, simeon, predictably,
# Nearest to about: triiodothyronine, cinema, clippers, asm, lessig, turbochargers, keeper, notaries,
# Nearest to american: exegetes, ruach, steaks, severance, sleepers, nippon, slab, signer,
# Nearest to after: unisex, opold, greenman, elimination, weekly, stampede, homophones, proofs,
# Nearest to by: chronos, kdf, morals, tnt, melito, antonescu, skunk, messageboard,
# Nearest to and: danza, twisted, seaton, vinyl, dunlop, emphasises, borghese, archduke,
# Nearest to five: trying, persecutors, polycrates, nagasaki, got, jehoram, rapeseed, colonist,
# Nearest to d: rfloor, nomination, peotone, scrupulous, stretches, sneakers, triangles, insensible,
# Nearest to articles: arable, dramatised, slacks, hinterland, catalysts, guile, anycast, solos,
# Nearest to scale: oulu, radical, louisiana, astatine, weil, transitioning, sonic, bisonoric,
# Nearest to heavy: reputed, mpaa, partially, tatiana, behaviors, wargames, spaniards, sloop,
# Nearest to derived: labial, breaded, aerosol, inflict, weidman, persons, howerd, plied,
# Nearest to egypt: pers, flourished, arnhem, lana, heracleidae, strobe, theosophists, marcuse,
# Nearest to powers: isotopes, milli, belting, ztt, provides, kant, aldiss, festival,
# Nearest to bbc: credence, jays, jura, cadr, marginalized, infamy, capriccio, ham,
# Nearest to creation: cce, morant, stu, goto, lenz, walesa, gradually, continuum,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.5640 0.0243 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.5447 0.0234 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.5410 0.0233 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.5307 0.0234 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.5441 0.0234 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.5082 0.0233 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.5225 0.0234 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.5239 0.0234 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.5251 0.0235 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.5579 0.0234 sec/batch
# Nearest to new: titus, peripherals, equivalence, incompletely, ahimelech, leges, collegiate, typee,
# Nearest to about: axe, arene, yunus, bower, sliders, cellulose, seating, deals,
# Nearest to american: hurt, conservatorship, mrl, hartmut, vestalia, drugged, bosna, psc,
# Nearest to after: chthonic, phylum, skilling, protium, espoo, fasl, speeds, cinder,
# Nearest to by: longbowman, bomis, kendal, judaeo, signifies, agee, crustacean, mourners,
# Nearest to and: fraktion, lutterworth, damascius, sara, stabilization, bettor, clarke, metaphilosophy,
# Nearest to five: pastoral, pearse, disinherited, fourfold, mailboxes, windowing, detrimental, uan,
# Nearest to d: spitfire, follett, commission, deb, applicants, academia, equilateral, lunches,
# Nearest to articles: faye, creditors, paperback, transforming, deadites, ksl, pombal, loathed,
# Nearest to scale: alpert, pangolins, speculator, waging, plutonic, halle, raeder, remote,
# Nearest to heavy: teshubah, digitized, nol, edicts, chlorofluorocarbons, levu, hopi, regia,
# Nearest to derived: cellspacing, circumvented, federally, fore, epa, dram, broadleaf, mcneill,
# Nearest to egypt: shea, gracchi, dumfries, gladius, mamoru, embassies, asterism, najibullah,
# Nearest to powers: airframe, soddy, ankara, nul, batswana, dress, groupe, cachet,
# Nearest to bbc: reals, loonie, uke, schodt, shotokan, actualization, karnstein, chili,
# Nearest to creation: haunting, lp, harbin, disjointed, pahlavi, shaktism, ideologue, ninlil,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.5242 0.0244 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.5272 0.0234 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.5196 0.0234 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.5100 0.0235 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.6038 0.0232 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.5249 0.0236 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.5033 0.0234 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.5278 0.0235 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.5224 0.0234 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.4819 0.0236 sec/batch
# Nearest to new: transliterating, substantial, annunzio, prostate, mortally, invasion, illustrious, pretenders,
# Nearest to about: bloomberg, nebulous, helter, invention, acorns, letter, somewhere, deviant,
# Nearest to american: dimmer, els, struma, worldcom, chu, fugitive, vacate, permission,
# Nearest to after: contralto, rosso, technique, clair, baryogenesis, orapa, undeniably, exporters,
# Nearest to by: irian, epoxy, romanic, inventing, sistine, interconnected, transhumanist, yuki,
# Nearest to and: proclamation, confession, pneumococcus, boying, hitchhiking, valvular, regular, chongqing,
# Nearest to five: sncb, donnell, ludwik, provisions, shall, blamed, shores, alexa,
# Nearest to d: bremsstrahlung, odd, eli, slight, biosynthesis, grattan, successively, trending,
# Nearest to articles: danios, daisy, wrecked, brienne, supercar, rascal, precincts, enslavable,
# Nearest to scale: ringen, deregulated, evidence, gripping, cuyahoga, gls, interestingly, mbasogo,
# Nearest to heavy: od, isin, jaw, ender, custodian, terrance, styling, sloan,
# Nearest to derived: suppers, cemac, cruel, torlakian, terengganu, foodstuffs, sharpe, maiden,
# Nearest to egypt: bacteriophage, bibliographic, aloft, encouraged, upgrade, igs, nuova, rel,
# Nearest to powers: bonhoeffer, coro, cartesian, barter, dismayed, possible, loess, lawson,
# Nearest to bbc: phanerozoic, loaded, leeuwarden, unequalled, sabbats, xx, adige, sopron,
# Nearest to creation: rup, hatha, liff, unsealed, zucker, solitaire, mannerisms, electricity,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4775 0.0246 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4887 0.0236 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.4781 0.0235 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.4841 0.0235 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4876 0.0236 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.4893 0.0235 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.4721 0.0234 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.4712 0.0232 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.4711 0.0233 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.4719 0.0235 sec/batch
# Nearest to new: bowen, sar, erred, unites, cri, consecutive, quack, spatial,
# Nearest to about: assailant, ned, kilmer, swindle, neuroleptic, unwin, nab, christianised,
# Nearest to american: reptilian, impressed, turtle, alba, gassendi, felons, neale, realistic,
# Nearest to after: genevieve, demi, liberty, observers, grander, verse, reassurance, stuffed,
# Nearest to by: misleadingly, journal, forges, taz, rbis, mullet, maja, hipper,
# Nearest to and: magnoliophyta, gottschalk, gallurese, pastel, satisfiable, rally, home, pasta,
# Nearest to five: mastered, mng, tutelary, falsetto, predictably, capitalists, musculature, disrespect,
# Nearest to d: nox, obfuscation, devise, sparrow, rasmussen, contributors, busier, bourke,
# Nearest to articles: carcinoma, premised, diomedes, inhabit, mazurek, gurney, lgiy, beneficiaries,
# Nearest to scale: lecturing, going, diplomatique, destinies, syracuse, cream, bionic, prabhakaran,
# Nearest to heavy: simplistic, faster, romantics, ole, rapidity, care, teaser, exposes,
# Nearest to derived: codebook, ladino, frenchy, preserved, nuit, labelling, linguist, armagh,
# Nearest to egypt: somers, godel, esat, boswell, vacancy, lahaye, preset, viollet,
# Nearest to powers: spiro, patenting, cylindrical, confessing, ensembles, party, dealerships, dxf,
# Nearest to bbc: hearses, distortions, backyard, fernando, edlin, adaptability, anathema, waltham,
# Nearest to creation: sectional, sotho, paraphrased, coupon, asymptotes, felony, safin, disparagingly,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4558 0.0244 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.4654 0.0234 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.4493 0.0234 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.4805 0.0232 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.4866 0.0235 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.4827 0.0236 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.4403 0.0233 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.4739 0.0234 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4757 0.0235 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.4627 0.0236 sec/batch
# Nearest to new: unfree, duisburg, entice, proteg, deccan, doe, quan, matic,
# Nearest to about: sps, boundary, themas, sweets, cu, vivant, zionism, learner,
# Nearest to american: may, bdp, fielded, lufthansa, kernow, bashing, smg, kinderhook,
# Nearest to after: sven, stoneman, shakuhachi, balrog, hackett, supine, poised, habitat,
# Nearest to by: mithraic, grasses, yvonne, wannsee, sauber, ivanhoe, barons, mortem,
# Nearest to and: montag, sack, wolf, sometime, expandability, interested, hillgruber, librorum,
# Nearest to five: oven, renamed, pyr, ergodic, cordially, frere, mrl, edit,
# Nearest to d: glycogenolysis, ecotage, esperantists, kjell, yoghurt, pointless, ladder, ninotchka,
# Nearest to articles: ensues, puranic, inhomogeneities, trabzon, babrak, waving, sexist, omb,
# Nearest to scale: lawgiver, pug, meaningless, repeater, moi, integrated, cga, done,
# Nearest to heavy: erects, forrestal, witten, inheritance, cyclically, dora, hava, caucuses,
# Nearest to derived: darkening, restaurateur, tutankhamun, reshaping, actuated, brunt, architects, militancy,
# Nearest to egypt: retrofitted, willow, mini, dato, appointments, jimmie, politics, artful,
# Nearest to powers: kub, ferrimagnetism, thirteen, bodyline, unambiguous, instructions, stalactites, stomachs,
# Nearest to bbc: diatomic, wang, tallapoosa, enthalpy, mml, figueres, vanish, offences,
# Nearest to creation: postprandial, antoninus, loc, tees, demise, ruthenian, webmuseum, cannonballs,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.4746 0.0242 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.4549 0.0229 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.4360 0.0232 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4304 0.0235 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.4350 0.0235 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.4289 0.0235 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4380 0.0234 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.4643 0.0235 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.4188 0.0234 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.4074 0.0233 sec/batch
# Nearest to new: cathedral, recapitulation, mier, prostitutes, vukovar, pashtunistan, ritorno, geoid,
# Nearest to about: gill, champlain, manner, soured, chronica, guarantor, ardor, soma,
# Nearest to american: vigilance, abolish, romanizations, vanuatu, gerrymandered, nuke, minsk, touchdown,
# Nearest to after: moody, deferment, catan, nowell, ontological, calorimetry, clannad, indus,
# Nearest to by: evens, ccg, marylebone, talmudic, noticeably, sorcerers, sozomen, furnishes,
# Nearest to and: optimal, miramar, farah, hunnish, bukovina, associates, incredulity, extremadura,
# Nearest to five: hypopituitarism, aqdas, tanner, chinon, broad, neuromuscular, bothnia, iambic,
# Nearest to d: theophoric, bromide, databank, hot, functors, resigning, semmelweis, emeric,
# Nearest to articles: yeast, dodecylcyclobutanone, compelled, needless, deceived, hiss, nominalism, seizure,
# Nearest to scale: gigantes, helsing, tuskegee, wilberforce, fabrique, unctad, reverts, sportspeople,
# ...
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 4.2142 0.0243 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 4.2015 0.0233 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 4.2069 0.0232 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 4.2023 0.0232 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 4.2091 0.0234 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 4.2189 0.0234 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 4.2242 0.0233 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 4.2065 0.0233 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 4.2137 0.0232 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 4.2120 0.0231 sec/batch
# Nearest to new: connecting, veterinarians, iterated, bessarabia, busses, deride, bozeman, tanoana,
# Nearest to about: ordeal, mamayev, onizuka, denominator, munster, bandwidth, turboexpress, vatsetis,
# Nearest to american: silenced, shelters, hillbilly, syringe, mass, intrigues, dwarfs, forensics,
# Nearest to after: rumen, eldorado, mano, ulrike, bodhidharma, immersion, panyu, miho,
# Nearest to by: dinosaurs, algebras, muse, greenery, quart, arose, majesties, regents,
# Nearest to and: mythography, anteater, rodan, ilan, infinitesimal, undefeated, binds, mexicana,
# Nearest to five: corundum, chemotherapeutic, strumming, choreographer, pullback, botha, homerun, foetus,
# Nearest to d: waste, prop, namely, although, telluride, engels, commodore, meaty,
# Nearest to articles: chilling, chola, tevet, deadlocked, shakuhachi, saladin, columbia, dissolved,
# Nearest to scale: lingual, heinlein, asdb, fertility, timaeus, anthologies, offseason, tongues,
# Nearest to heavy: philokalia, jutland, heligoland, crows, bargain, bengali, mahwah, minesweeper,
# Nearest to derived: stereoisomers, hur, climaxed, undertones, ibizan, klaus, cranberries, saddled,
# Nearest to egypt: hbf, accomplished, attorney, mili, cardelli, spongiform, josh, protected,
# Nearest to powers: infertility, tuple, completed, brewery, kri, chartist, competing, zubaydah,
# Nearest to bbc: aurangzeb, nizam, ibelin, isolate, lieutenant, mercer, samadhi, curtin,
# Nearest to creation: karlovac, motion, amasis, debased, isis, picker, marketable, everlasting,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 4.2031 0.0244 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 4.2026 0.0231 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 4.2025 0.0232 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 4.2207 0.0233 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.2210 0.0233 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.2188 0.0232 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 4.2120 0.0233 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 4.2085 0.0233 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 4.2814 0.0230 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.2013 0.0235 sec/batch
# Nearest to new: devoid, coc, albom, aa, byrne, tantra, differentiable, nyman,
# Nearest to about: chimneys, weatherman, degas, uel, simenon, encoders, claudio, conveys,
# Nearest to american: sonatas, breastfeeding, geats, timbres, coalition, saipan, multimate, phraseology,
# Nearest to after: daybreak, cobalt, wipes, unequivocal, johan, sterol, rhenish, intervals,
# Nearest to by: neat, antoine, hunmin, crackdown, haste, qaradawi, budge, patay,
# Nearest to and: replacements, livelihood, prevents, killian, thermidor, advent, loom, hemophilia,
# Nearest to five: bets, foreseen, wlad, grown, hippodrome, supersede, skipper, vestigial,
# Nearest to d: vorkosigan, sphincter, uballit, orbison, fertilized, mos, craftsmanship, subsequent,
# Nearest to articles: inklings, pastorius, hood, kaddish, weiner, gbp, vests, cichlid,
# Nearest to scale: bourne, heaps, crumble, distortion, cynics, oxidizes, oxidise, picard,
# Nearest to heavy: runciman, scheme, sizing, eich, transactional, mamre, wineries, molybdenum,
# Nearest to derived: christened, granddaughter, stefan, absconded, exempt, nazca, faroe, imre,
# Nearest to egypt: insiders, postpartum, adequate, shattuck, kintyre, ailments, crews, iphigenia,
# Nearest to powers: dpi, solzhenitsyn, skelter, adjusting, vulnerable, strive, ortiz, ledger,
# Nearest to bbc: rennet, goukouni, defusal, supposition, hops, hangover, warmia, salvific,
# Nearest to creation: noree, sobel, liquefaction, sati, buckyballs, dying, hemphill, finishes,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 4.2140 0.0243 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.2138 0.0234 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 4.2136 0.0232 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.1976 0.0233 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 4.1934 0.0233 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 4.2043 0.0232 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 4.1994 0.0233 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 4.2195 0.0232 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 4.2048 0.0233 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 4.2001 0.0233 sec/batch
# Nearest to new: damning, jonah, counterfeit, tempus, arenas, homer, iconoclast, landfill,
# Nearest to about: midler, issas, chos, pago, bestiaries, dessalines, wuhan, coach,
# Nearest to american: hubble, invades, adapter, antipope, interconnecting, chukotka, reciprocate, nattiez,
# Nearest to after: defender, higson, constrain, robocop, auteurism, bourbaki, zuma, stalker,
# Nearest to by: ella, tentacles, nonterminals, reversibly, die, asenath, nutritious, ufa,
# Nearest to and: resisters, signers, blink, quotes, wilhelm, drifted, xenocrates, desiring,
# Nearest to five: acs, pressured, accede, scanty, jani, karmal, granta, bluerhinos,
# Nearest to d: congenial, andalusia, unexpected, pillar, radiocommunication, worship, legally, hariri,
# Nearest to articles: theses, staden, diners, denotes, trilled, scrolls, rss, pneumoniae,
# Nearest to scale: continued, purgatorio, gail, authority, behavior, divan, ebla, closures,
# Nearest to heavy: microbiological, lolf, lifesaving, deadheads, vilayet, knowledgeable, lavinia, dismissive,
# Nearest to derived: oses, lodged, collett, defective, eastern, electrolytic, recklessly, cohorts,
# Nearest to egypt: exterminating, lhasa, priapus, sonoran, bounds, vane, admittedly, camino,
# Nearest to powers: crusts, requests, irritant, montpensier, armature, adjusting, pasolini, doctoral,
# Nearest to bbc: jackals, nightmarish, chivalrous, shunters, unbaptized, rata, santos, astrometric,
# Nearest to creation: commodores, ritalin, scalpel, strictness, generals, gemayel, accusers, literate,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 4.2075 0.0243 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 4.2056 0.0234 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 4.1854 0.0233 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 4.2077 0.0233 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 4.2020 0.0233 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 4.1925 0.0234 sec/batch
# Epoch 10/10 Iteration: 116700 Avg. Training loss: 4.2141 0.0233 sec/batch
# Epoch 10/10 Iteration: 116800 Avg. Training loss: 4.2111 0.0233 sec/batch
# Epoch 10/10 Iteration: 116900 Avg. Training loss: 4.2086 0.0233 sec/batch
# Epoch 10/10 Iteration: 117000 Avg. Training loss: 4.2068 0.0232 sec/batch
# Nearest to new: lavos, aneristic, suited, horeb, ethiopians, jagan, dwelt, doubles,
# Nearest to about: deacon, daewoo, compensatory, suda, paradis, pershing, magnates, teleportation,
# Nearest to american: limes, disbarment, brahms, infusions, planner, samhain, feminist, fearless,
# Nearest to after: sanc, leipzig, muscles, privateer, toilet, destroy, spruce, fusiliers,
# Nearest to by: scholl, sahelian, marshallese, salaino, manipulations, delicious, allergy, polyhedron,
# Nearest to and: receptus, committee, tuireadh, significand, chaitin, galileo, guessed, promptly,
# Nearest to five: visited, preparedness, naqada, coventry, emilie, sellars, realign, stabilizing,
# Nearest to d: salsa, picks, followers, rann, daugava, numismatic, multiprocessing, rubin,
# Nearest to articles: jaco, triangular, bitch, bean, sophist, card, besides, kahan,
# Nearest to scale: privatized, hales, kershaw, bastard, occupies, dumfries, oblige, securely,
# Nearest to heavy: welker, spurs, expressionists, spore, dickerson, creaky, dri, spyglass,
# Nearest to derived: gallop, sarris, townlands, deter, incl, invaders, marshes, largo,
# Nearest to egypt: vicente, pleased, sociologist, ukraine, kline, midwinter, stoves, ghaznavid,
# Nearest to powers: xxxiv, mala, translating, link, tr, shouted, istituto, expedients,
# Nearest to bbc: hacked, every, cruising, feodor, wessex, misled, mako, stasis,
# Nearest to creation: toomer, hindsight, sharper, religio, dorset, landscapes, kilojoules, harshest,
# Epoch 10/10 Iteration: 117100 Avg. Training loss: 4.2099 0.0244 sec/batch
# Epoch 10/10 Iteration: 117200 Avg. Training loss: 4.2040 0.0232 sec/batch
# Epoch 10/10 Iteration: 117300 Avg. Training loss: 4.2058 0.0233 sec/batch
# Epoch 10/10 Iteration: 117400 Avg. Training loss: 4.2008 0.0233 sec/batch
# Epoch 10/10 Iteration: 117500 Avg. Training loss: 4.2031 0.0232 sec/batch
# Epoch 10/10 Iteration: 117600 Avg. Training loss: 4.1932 0.0228 sec/batch
# Epoch 10/10 Iteration: 117700 Avg. Training loss: 4.1969 0.0231 sec/batch
# Epoch 10/10 Iteration: 117800 Avg. Training loss: 4.1786 0.0230 sec/batch
# Epoch 10/10 Iteration: 117900 Avg. Training loss: 4.1869 0.0232 sec/batch
# Epoch 10/10 Iteration: 118000 Avg. Training loss: 4.1941 0.0233 sec/batch
# Nearest to new: papiamento, lesund, jerky, mundi, mauryan, professional, worrying, petitioning,
# Nearest to about: transmitters, incheon, corresponded, bronzes, turret, hooked, bloodedness, debilitating,
# Nearest to american: prejudicial, clive, usque, gpp, goodfellas, tubulidentata, electroconvulsive, enclosure,
# Nearest to after: eurofighter, cabalistic, abiword, premium, oscar, arendt, moldings, flowed,
# Nearest to by: leguminous, derby, lorenzini, jl, recorders, roeg, justifiably, archaeologist,
# Nearest to and: flattering, rhoads, hesitant, forrester, daimler, camelot, cerberus, culminate,
# Nearest to five: unseen, convertibility, cheque, losses, naoh, humanistic, dipyramid, elmira,
# Nearest to d: suspensions, bookstores, eskimos, mississippians, turing, catalyze, hors, lucretia,
# Nearest to articles: midwife, bnf, chandelier, inefficiency, vers, antares, crying, ultrasonography,
# Nearest to scale: thinning, sukkot, gott, editorials, systems, hesitation, enforcer, essai,
# Nearest to heavy: zz, coaching, tero, theo, gondar, hurtful, gotham, precautionary,
# Nearest to derived: chop, sprockets, canines, dynamic, litigant, assessed, alshehhi, horst,
# Nearest to egypt: copperfield, tularemia, slashdot, cassini, adamson, hemiparesis, extrapolation, untamed,
# Nearest to powers: bosnian, fianna, ts, unitar, relocate, flowed, guidebook, adad,
# Nearest to bbc: archaeologically, argyll, pilsener, populares, ternary, movin, seems, eftpos,
# Nearest to creation: punishable, gara, aggressively, expel, defensa, accolades, aged, hollows,
# Epoch 10/10 Iteration: 118100 Avg. Training loss: 4.1881 0.0242 sec/batch
# Epoch 10/10 Iteration: 118200 Avg. Training loss: 4.2004 0.0234 sec/batch
# Epoch 10/10 Iteration: 118300 Avg. Training loss: 4.1984 0.0232 sec/batch
# Epoch 10/10 Iteration: 118400 Avg. Training loss: 4.1943 0.0235 sec/batch
# Epoch 10/10 Iteration: 118500 Avg. Training loss: 4.1936 0.0235 sec/batch
# Epoch 10/10 Iteration: 118600 Avg. Training loss: 4.2275 0.0234 sec/batch
# Epoch 10/10 Iteration: 118700 Avg. Training loss: 4.2006 0.0233 sec/batch
# Epoch 10/10 Iteration: 118800 Avg. Training loss: 4.2081 0.0233 sec/batch
# Epoch 10/10 Iteration: 118900 Avg. Training loss: 4.2056 0.0231 sec/batch
# Epoch 10/10 Iteration: 119000 Avg. Training loss: 4.2202 0.0230 sec/batch
# Nearest to new: predominate, gives, trollhunters, uncharacteristic, horned, borges, perineum, crawford,
# Nearest to about: bremerhaven, panthera, herut, fret, unskilled, sufficed, transmitting, vert,
# Nearest to american: downloading, erasable, query, vaccine, dect, confident, underwent, luke,
# Nearest to after: kungliga, ramsay, built, record, shone, partaking, gwangju, gluconeogenesis,
# Nearest to by: sledge, fillings, mantis, focus, relents, choral, fires, occurrence,
# Nearest to and: romano, melvin, subsystems, schwa, reprogrammed, champaign, productivity, quell,
# Nearest to five: elms, timed, menlo, rump, engstrom, enoch, symptomatology, sfr,
# Nearest to d: mujibur, constant, cherish, withdrawals, empires, biloxi, rutles, coordinated,
# Nearest to articles: incorruptible, nim, housings, skipper, anatta, grappelli, numerological, minimizes,
# Nearest to scale: larimer, rnir, accentuated, elks, douglass, undeserved, fuzes, neuroscientists,
# Nearest to heavy: keyes, remarque, eretz, chez, commandants, dimebag, amniotes, theatrum,
# Nearest to derived: shri, valladolid, abscess, kadima, pogrom, haunts, avenue, magdalena,
# Nearest to egypt: woodcock, federals, engstrom, parity, surfacing, setbacks, linkers, aeneas,
# Nearest to powers: buzz, rates, zadar, ect, rudiments, elmira, refraining, frontiersman,
# Nearest to bbc: raspberry, priors, ssy, draconis, stacks, lawfully, wondering, aoe,
# Nearest to creation: capi, faithfulness, marquess, bowels, stupid, kaveri, romania, alcs,
# Epoch 10/10 Iteration: 119100 Avg. Training loss: 4.2206 0.0242 sec/batch
# Epoch 10/10 Iteration: 119200 Avg. Training loss: 4.1992 0.0232 sec/batch
# Epoch 10/10 Iteration: 119300 Avg. Training loss: 4.2361 0.0233 sec/batch
# Epoch 10/10 Iteration: 119400 Avg. Training loss: 4.2090 0.0232 sec/batch
# Epoch 10/10 Iteration: 119500 Avg. Training loss: 4.1907 0.0231 sec/batch
# Epoch 10/10 Iteration: 119600 Avg. Training loss: 4.2036 0.0231 sec/batch
# Epoch 10/10 Iteration: 119700 Avg. Training loss: 4.2133 0.0235 sec/batch
# Epoch 10/10 Iteration: 119800 Avg. Training loss: 4.1929 0.0233 sec/batch
# Epoch 10/10 Iteration: 119900 Avg. Training loss: 4.2003 0.0233 sec/batch
# Epoch 10/10 Iteration: 120000 Avg. Training loss: 4.2220 0.0232 sec/batch
# Nearest to new: attractor, fontvieille, salic, ingushetia, arimathea, donatists, collin, yn,
# Nearest to about: hitpa, zam, hydrophobic, experienced, cinnamon, would, bornholm, estrangement,
# Nearest to american: atil, widescreen, undeserved, freeware, hinge, nee, afro, declarations,
# Nearest to after: astigmatism, ammi, soloists, mano, attributed, proscribed, refractive, dae,
# Nearest to by: sanctus, commandment, gimmicks, dearborn, following, valery, bodhisattva, ladin,
# Nearest to and: ramjet, cargo, ibu, crisscrossed, batty, communes, looking, nitz,
# Nearest to five: congestion, wma, desmodromic, ancillon, zimmermann, heterosexism, melds, gennadius,
# Nearest to d: isoleucine, county, fernando, ritualised, unheated, farian, seized, genscher,
# Nearest to articles: kernow, view, geodesic, exchanged, canaanites, release, spells, decipher,
# Nearest to scale: scots, statistical, akayev, confiscated, dog, shame, suomen, separatists,
# Nearest to heavy: talal, delighted, bisexual, nobelprize, circumstantial, carlin, supergravity, footprints,
# Nearest to derived: forestry, wilma, dragsters, milieu, hype, pernicious, storks, surfboard,
# Nearest to egypt: watchmen, nicene, plank, minimising, ninlil, pumpkin, woof, lord,
# Nearest to powers: maximal, diels, johnston, robie, amyntas, coercing, acid, gwr,
# Nearest to bbc: newspeak, recreates, embryos, saiyan, airwaves, alus, isma, stencil,
# Nearest to creation: slimy, spinners, weir, flour, kramer, enacts, renin, sam,
# Epoch 10/10 Iteration: 120100 Avg. Training loss: 4.2033 0.0243 sec/batch
# Epoch 10/10 Iteration: 120200 Avg. Training loss: 4.1936 0.0232 sec/batch
# Epoch 10/10 Iteration: 120300 Avg. Training loss: 4.1937 0.0232 sec/batch
# Epoch 10/10 Iteration: 120400 Avg. Training loss: 4.2059 0.0234 sec/batch
# Epoch 10/10 Iteration: 120500 Avg. Training loss: 4.2209 0.0234 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
